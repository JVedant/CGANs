# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
def get_data(url):
    r = requests.get(url)
    return r

html_data = get_data("https://www.datastro.eu/explore/dataset/nasahubble/images/?disjunctive.album_name_tags&sort=photo_title")
soup = BeautifulSoup(html_data.content, 'html.parser')

#warning = soup.findAll('img', class_="image-thumb")
#image_container = warning.nextSibling
#image = image_container.findAll('a')
#example = image[5]

# %%
images = soup.find('img', class_="odswidget-record-image__image ng-scope")

# %%
images

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>NASA Hubble Space Telescope Pictures / Images du télescope spatial Hubble de la NASA — Datastro</title>
# <link href="/static/vendor/font-awesome-4.7.0/css/font-awesome.min.css" rel="stylesheet" type="text/css"/>
# <link href="/static/vendor/normalize/normalize.css" rel="stylesheet" type="text/css"/>
# <link href="/static/pictos/odsui/odsui.css" rel="stylesheet" type="text/css"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="en" http-equiv="Content-Language"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://s3.amazonaws.com/aws-ec2-us-east-1-opendatasoft-staticfileset/datastro/favicon?tstamp=149812113894" rel="shortcut icon"/>
# <link href="https://www.datastro.eu/explore/dataset/nasahubble/images/" hreflang="en" rel="alternate">
# ...

# %%
'''url = "https://esahubble.org/images/viewall/"
r = requests.get(url)
soup = BeautifulSoup(r.content, "html.parser")
script = soup.find_all('script')[1].text.strip()[13:-10]
data = json.loads(script)'''
